# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../datasets/LinearRegression/train_energy_data.csv')
df.head()
# Out:
#   Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0   Residential            7063                   76               10
# 1    Commercial           44372                   66               45
# 2    Industrial           19255                   37               17
# 3   Residential           13265                   14               41
# 4    Commercial           13375                   26               18
#
#    Average Temperature Day of Week  Energy Consumption
# 0                29.84     Weekday             2713.95
# 1                16.72     Weekday             5744.99
# 2                14.30     Weekend             4101.24
# 3                32.82     Weekday             3009.14
# 4                11.92     Weekday             3279.17

# %%
df.isnull().sum()
# Out:
# Building Type          0
# Square Footage         0
# Number of Occupants    0
# Appliances Used        0
# Average Temperature    0
# Day of Week            0
# Energy Consumption     0
# dtype: int64

# %%
dfc=df.copy()
df=df.drop(['Building Type','Day of Week'],axis='columns')

scaler=StandardScaler()
# df['Appliances Used']=scaler.fit_transform(df['Appliances Used'])
df['Average Temperature']=scaler.fit_transform(df['Average Temperature'])
df['Energy Consumption']=scaler.fit_transform(df['Energy Consumption'])
df['Number of Occupants']=scaler.fit_transform(df['Number of Occupants'])
df['Square Footage']=scaler.fit_transform(df['Square Footage'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 6
#       4 scaler=StandardScaler()
#       5 # df['Appliances Used']=scaler.fit_transform(df['Appliances Used'])
# ----> 6 df['Average Temperature']=scaler.fit_transform(df['Average Temperature'])
#       7 df['Energy Consumption']=scaler.fit_transform(df['Energy Consumption'])
#       8 df['Number of Occupants']=scaler.fit_transform(df['Number of Occupants'])
#
# File c:\Users\Youssef\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
# ...

# %%
plt.scatter(df['Energy Consumption'],df['Number of Occupants'])
