# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../datasets/Outliers/AB_NYC_2019.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df[df["neighbourhood"]=="Kensington"]
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 258       63546                     Large and Cozy Private Bedroom     308652
# 397      125594                 SUPER BIG AND COZY PRIVATE BEDROOM     308652
# 738      267652              Private clean pleasant spacious room.     164675
# 786      282341                Kensington/Ditmas Park pied-a-terre    1471384
# ...         ...                                                ...        ...
# 47286  35676024  Private bedroom with lovely, spacious shared area  177507494
# 47295  35679309                  A unique cozy 2 bedroom apartment  268396733
# 47512  35777392    SPACIOUS STUDIO FLAT In Tree-Lined Neighborhood  117987098
# 47963  36003288           Apartment in Kensington area of Brooklyn  161196794
# 48216  36142215               SUMMER RENTAL IN SUNNY SPACIOUS ROOM   41484943
#
# ...

# %%
min_price,max_price=df['price'].quantile([0.002,0.998])

print(min_price)
print(max_price)
# Out:
# 22.0
# 2000.0

# %%
df2=df[(df['price']>min_price) & (df['price']<max_price)]
df2.sample(10)
# Out:
#              id                                               name    host_id  \
# 3980    2487073    18th Floor Bright Bedroom with Private Bathroom    6194434
# 15868  12834317                 Private 1 Bedroom Garden Level Apt    3404004
# 44599  34316788    Central Park West: 3 Bedroom + 2 Bath Jewel-box  258159396
# 13307  10015195                     Madison Avenue 1 Bedroom Suite   50760546
# 7424    5523413                                Oasis in Kensington   12212944
# 34098  27023307  Large, True 1BR - Heart of Nolita/Soho/LittleI...    3399151
# 7855    6006387                   FABULOUS SUNNY BEDROOM IN HARLEM   31181172
# 42290  32821152         1BR SoHo Apt w/ your own private backyard.   96773131
# 14322  11147993                     A SUPERB One Bedroom Apartment   57954654
# 26153  20857866                      Nettie's Brooklyn Dream Space  105828086
#
#                   host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %%
df2.shape
# Out:
# (48676, 16)
